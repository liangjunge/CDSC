# %%
#coding=utf-8 
import os
#获取目标文件夹的路径
filedir = os.getcwd()+'/n'
#获取当前文件夹中的文件名称列表  
filenames=os.listdir(filedir)
#打开当前目录下的result.txt文件，如果没有则创建
f=open('targe.txt','w')
#先遍历文件名
for filename in filenames:
    filepath = filedir+'/'+filename
    #遍历单个文件，读取行数
    for line in open(filepath,'rb'):
        line = str(line)
        f.writelines(line)
        #f.write('\n')
#关闭文件
f.close()

# %%
import os
from os import listdir
filepath=os.getcwd()+ '\\' + 'pos'    
filename_list=listdir(filepath)
h = []
for path in filename_list:
    #print(path)
    f = open(r'pos' + '\\' +path,'rb')
    neirong = f.read().decode('utf-8')
    h.append(neirong)
    f.close()

print('\n'.join(h).encode('utf-8'))
f = open('2.txt','wb+')
f.write('\n'.join(h).encode('utf-8'))
f.close()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# -*- coding:utf-8 -*-
#os模块中包含很多操作文件和目录的函数
import os
from os import listdir
#获取目标文件夹的路径
meragefiledir = os.getcwd()+'\\pos'
#获取当前文件夹中的文件名称列表
filenames=os.listdir(meragefiledir)
#打开当前目录下的result.txt文件，如果没有则创建
#文件也可以是其他类型的格式，如result.js
file=open('result.txt','w')
#向文件中写入字符
#file.write('python\n')

#先遍历文件名
for filename in filenames:
    filepath=meragefiledir+'\\'+filename
    #遍历单个文件，读取行数
    for line in open(filepath):
        file.writelines(line)
    file.write('\n')

#关闭文件
file.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-4c8e097d1837> in <module>()
#      17     filepath=meragefiledir+'\\'+filename
#      18     #遍历单个文件，读取行数
# ---> 19     for line in open(filepath):
#      20         file.writelines(line)
#      21     file.write('\n')
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0x93 in position 596: illegal multibyte sequence

# %%
#coding=utf-8 
import os
#获取目标文件夹的路径
filedir = os.getcwd()+'/n'
#获取当前文件夹中的文件名称列表  
filenames=os.listdir(filedir)
#打开当前目录下的result.txt文件，如果没有则创建
f=open('target.txt','w')
#先遍历文件名
for filename in filenames:
    filepath = filedir+'/'+filename
    #遍历单个文件，读取行数
    for line in open(filepath):
        f.writelines(line)
        f.write('\n')
#关闭文件
f.close()

# %%
fpa=open('computer.txt','rb')
fpb=open ('science.txt','rb')
fpc=open('common.txt',"w+")
 
aArr=[]
for linea in fpa.readlines():
    aArr.append(linea)
bArr=[]
for lineb in fpb.readlines():
     bArr.append(lineb)
 
     lenth=len(aArr)
     if lenth>len(bArr):
        lenth=len(bArr)
for ii in range(lenth):
    if aArr[ii] == bArr[ii]:
        fpc.write(aArr[ii])
fpa.close()
fpb.close()
fpc.close()

# %%
fpa=open('computer.txt','r')
fpb=open('science.txt','r')
fpc=open('common.txt','w')
a=[]
b=[]
linesa = fpa.read()
for linea in linesa:
    a.append(linea)
linesb = fpb.read()
for lineb in linesb:
    b.append(lineb)
    length = len(a)
    if (lenth>len(b)):
        length = len(b)

for i in range(100000):
    if (a[i]==b[i]):
        fpc.write(a[i])
        i +=1
fpa.close()
fpb.close()
fpc.close()

# %%
import pandas as pd
com = pd.read_csv('computer.txt','utf-8')
com = com.dropna()
com= com.values.tolist()
sci = pd.read_csv('science.txt','utf-8')
sci = sci.dropna()
sci = sci.values.tolist()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """

# %%
common=[]
for line in com:
    if line in sci:
        common.append(line)
        count(line) = count(line)+1
        line = str(line)
        
print(common)
# Out:
#   File "<ipython-input-187-b4e461d8d490>", line 5
#     count(line) = count(line)+1
#     ^
# SyntaxError: can't assign to function call

# %%
for line in common:
    line = str(line)
    f = open('xiangsi.txt','w')
    f.write(line)
f.close()

# %%
from collections import Counter
## 计算词频的例子
def com_tf():
    f = open('./computer.txt', 'rb')
    data = f.read()
    wlist = 
    num_dict = Counter(wlist)  # 统计词频

    # 统计结果写入result.txt(字典的遍历)
    for (k, v) in num_dict.items():
        open('data/result.txt', 'a+').write(str(k) + ' ' + str(v) + '\n')   # 将k，v转换为str类型


if __name__ == '__main__':
    com_tf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-8f13ed218419> in <module>()
#      12
#      13 if __name__ == '__main__':
# ---> 14     com_tf()
#
# <ipython-input-90-8f13ed218419> in com_tf()
#       4     f = open('./computer.txt', 'rb')
#       5     data = f.read()
# ----> 6     num_dict = Counter(wlist)  # 统计词频
#       7
#       8     # 统计结果写入result.txt(字典的遍历)
#
# NameError: name 'wlist' is not defined

# %%
from collections import Counter
com = pd.read_csv('computer.txt','utf-8')
com = com.dropna()
com= com.values.tolist()
com = str(com)
#com = com.split()
common = pd.read_csv('xiangsi.txt','utf-8')
#common= common.dropna()
#common = str(pivots)
#common = common.split()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   import sys

# %%
com
# Out:
# "[['info video sound card sigma design  called win storm  card called legend   info appreciated incuding performance pricing  availability  thanks   srinus'], ['article chri almy write   trust hard disk sound  floppy thouoght mount disk  anoying deal problem arise  window mount unmount  window part upgrade soon  vendor    chri    trust safer previous  compression program integrate kernal nearly  impossible delete'], ['doe documentation mouse driver got  got window window manual doe come documentation  particular know turn speed  window greater sensitivity needed play various  game esp wing     carlo niederstrasser thing infinite  princeton planetary society universe human  stupidity sure  einstein   astra ardua nostra'], ['win downloaded icon bmp figure  change wallpaper icon help appreciated    thanx   brando   please mail'], ['unusual happen  background system mitsubishus meg hard drive  running smartdrv version come window  rarely window program called disk technician  gold diagno
# ...

# %%
common
# Out:
# Empty DataFrame
# Columns: [['friend mine please send answer directly mail  adress    highspeed analog digital board   hello lady gentleman   looking highspeed board sampling rate mhz  resolution bit sampling rate arranged interleave mode  time equivalent sampling yield time higher sampling rate  converter non interleave mode   board content converter similar analog device  available faster   board bit slot isa specification better please  send email       thanks advance help   sincerely   matthia hansch  ikph university hannover germany       andrea heinbokel     wisdom print shirt']]
# Index: []

# %%
for line in common:
    
    if line in com:
        line.count
        
        (line)
        print(line,line.count)
# Out:
# ['friend mine please send answer directly mail  adress    highspeed analog digital board   hello lady gentleman   looking highspeed board sampling rate mhz  resolution bit sampling rate arranged interleave mode  time equivalent sampling yield time higher sampling rate  converter non interleave mode   board content converter similar analog device  available faster   board bit slot isa specification better please  send email       thanks advance help   sincerely   matthia hansch  ikph university hannover germany       andrea heinbokel     wisdom print shirt'] <built-in method count of str object at 0x000001D7546046B0>

# %%
fa=open('computer.txt','r')
fb=open('xiangsi.txt','r')
fa=fa.read()
fb=fb.read()
for i in range(10000):
    for line in fa:
        for each in fb:
            if fa[i]==fb[i]:
                count(fa[i])
                i+=1
print(fa[i],count(fa[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-e44b693e7978> in <module>()
#       7         for each in fb:
#       8             if fa[i]==fb[i]:
# ----> 9                 count(fa[i])
#      10                 i+=1
#      11 print(fa[i],count(fa[i]))
#
# NameError: name 'count' is not defined

# %%
for line in common:
    for each in com:
        if line == each:
            line.count+=1
print(line,line.count)
# Out:
# ['friend mine please send answer directly mail  adress    highspeed analog digital board   hello lady gentleman   looking highspeed board sampling rate mhz  resolution bit sampling rate arranged interleave mode  time equivalent sampling yield time higher sampling rate  converter non interleave mode   board content converter similar analog device  available faster   board bit slot isa specification better please  send email       thanks advance help   sincerely   matthia hansch  ikph university hannover germany       andrea heinbokel     wisdom print shirt'] <built-in method count of str object at 0x000001D7546046B0>

# %%
count=0
preMajor=''
for major in majors:
    if major==preMajor:
        count+=1
    else:
        if  len(preMajor)>0:
            print(preMajor,count)
        preMajor=major
        count=1
        
if  len(preMajor)>0:
    print (preMajor,count)

# %%
from collections import Counter

for line in pivots:
    if line in com:
        Count(line)
print(line,Counter(line))
# Out:
# [] Counter({'[': 1, ']': 1})

# %%
def wordcount(str):
    # 文章字符串前期处理
    strl_ist = str.replace('\n', '').lower().split(' ')
    count_dict = {}
    # 如果字典里有该单词则加1，否则添加入字典
    for str in strl_ist:
        if str in count_dict.keys():
            count_dict[str] = count_dict[str] + 1
        else:
            count_dict[str] = 1
    #按照词频从高到低排列
    count_list=sorted(count_dict.iteritems(),key=lambda x:x[1],reverse=True)
    return count_list
print wordcount(str_context)
