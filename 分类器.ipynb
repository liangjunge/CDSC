# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from datetime import date

# %%
data = pd.read_csv('./movie_data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 2787: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-cfe7d349a2e8> in <module>()
# ----> 1 data = pd.read_csv('./movie_data.csv')
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#     980                 raise ValueError('skipfooter not supported for iteration')
#     981
# --> 982         ret = self._engine.read(nrows)
#     983
#     984         if self.options.get('as_recarray'):
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1717     def read(self, nrows=None):
#    1718         try:
# -> 1719             data = self._reader.read(nrows)
#    1720         except StopIteration:
#    1721             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read (pandas\_libs\parsers.c:10862)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory (pandas\_libs\parsers.c:11138)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas\_libs\parsers.c:12175)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data (pandas\_libs\parsers.c:14136)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14972)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 2787: invalid start byte

# %%
data
# Out:
#                                        ,sentiment,review
# 0      11841,1,"['1974', 'teenager', 'martha', 'moxle...
# 1      19602,0,"['ok', 'really', 'like', 'kris', 'kri...
# 2      45519,0,"['spoiler', 'read', 'think', 'watchin...
# 3      25747,1,"['hi', 'people', 'seen', 'wonderful',...
# 4      42642,0,"['recently', 'bought', 'dvd', 'forget...
# 5      31902,1,"['leave', 'braik', 'put', 'good', 'sh...
# 6      30346,1,"['nathan', 'detroit', 'frank', 'sinat...
# 7      12363,1,"['understand', 'crash', 'course', 'ri...
# 8      32490,1,"['impressed', 'chavez', 'stance', 'gl...
# 9      26128,1,"['movie', 'directed', 'renny', 'harli...
# 10     14227,0,"['lived', 'u', 'p', 'let', 'tell', 'f...
# 11     26376,1,"['hidden', 'frontier', 'notable', 'lo...
# 12     44173,0,"['ago', 'seen', 'sleuth', '1972', 'tw...
# 13     12968,0,"['french', 'first', 'apparently', 'li...
# 14     32104,1,"['strange', 'movie', 'unlike', 'anyth...
# 15     17844,0,"['saw', 'movie', 'strength', 'single'...
# 16     43460,0,"['great', 'philosophical', 'questions...
# 17     8369,1,"['cast', 'surfer', 'dude', 'beach', 's...
# 18     15055,0,"['high', 'hopes', 'one', 'changed', '...
# 19     6338,1,"['set', 'near', 'poor', 'working', 'cl...
# 20     15301,0,"['opulent', 'sets', 'sumptuous', 'cos...
# 21     46250,0,"['saw', 'film', 'got', 'screwed', 'fi...
# 22     45580,0,"['getting', 'little', 'tired', 'peopl...
# 23     24647,0,"['offensive', 'liked', 'movie', 'prob...
# 24     46712,0,"['else', 'say', 'movie', 'except', 'p...
# 25     4150,1,"['certain', 'aspects', 'punishment', '...
# 26     42460,0,"['first', 'like', 'tell', 'comics', '...
# 27     29079,1,"['take', 'say', 'lightly', 'seen', 'm...
# 28     19412,0,"['love', 'jurassic', 'park', 'movies'...
# 29     34839,1,"['first', 'series', 'lost', 'kicked',...
# ...                                                  ...
# 49970  7877,1,"['tom', 'fontana', 'unforgettable', 'o...
# 49971  37619,0,"['last', 'weekend', 'bought', 'zombie...
# 49972  5072,1,"['watched', 'first', 'moments', 'tcm',...
# 49973  2163,1,"['saw', 'movie', 'first', 'time', '198...
# 49974  38804,0,"['al', 'pacino', 'kim', 'basinger', '...
# 49975  6921,1,"['stanwyck', 'villainous', 'best', 'ro...
# 49976  38984,0,"['allegation', 'aggravated', 'sexual'...
# 49977  27469,1,"['thought', 'movie', 'wonderfully', '...
# 49978  16921,0,"['like', 'people', 'wait', 'see', 'oc...
# 49979  35665,1,"['dark', 'comedy', 'gallows', 'humor'...
# 49980  24152,0,"['probably', 'contain', 'spoilers', '...
# 49981  43095,0,"['must', 'one', 'guy', 'america', 'li...
# 49982  18983,0,"['plot', 'trucker', 'kristofferson', ...
# 49983  32230,1,"['ladies', 'man', 'laugh', 'loud', 'f...
# 49984  17089,0,"['well', 'artyfartyrati', 'cannes', '...
# 49985  14650,0,"['director', 'probably', 'still', 'ea...
# 49986  39512,0,"['know', 'bus', 'someone', 'decides',...
# 49987  48600,0,"['five', 'minutes', 'movie', 'realize...
# 49988  15430,0,"['laughing', 'much', 'long', 'time', ...
# 49989  14935,0,"['love', 'dissing', 'movie', 'peers',...
# 49990  46884,0,"['ok', 'think', 'tv', 'show', 'kind',...
# 49991  20757,0,"['big', 'disappointment', 'clash', 'n...
# 49992  41993,0,"['cassidy', 'kacia', 'brady', 'puts',...
# 49993  32103,1,"['rapid', 'intercutting', 'scenes', '...
# 49994  30403,1,"['girlfight', 'came', 'reviews', 'pra...
# 49995  21243,0,"['ok', 'lets', 'start', 'best', 'buil...
# 49996  45891,0,"['british', 'heritage', 'film', 'indu...
# 49997  42613,0,"['even', 'know', 'begin', 'one', 'fam...
# 49998  43567,0,"['richard', 'tyler', 'little', 'boy',...
# 49999  2732,1,"['waited', 'long', 'watch', 'movie', '...
#
# [50000 rows x 1 columns]

# %%
pos = data[data['sentiment'] == "1"]
neg = data[data['sentiment'] == "0"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'sentiment'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-7d24a858d576> in <module>()
# ----> 1 pos = data[data['sentiment'] == "1"]
#       2 neg = data[data['sentiment'] == "0"]
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# D:\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'sentiment'
